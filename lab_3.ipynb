# %% [markdown]
# <a href="https://colab.research.google.com/github/SofiaShvedova/Programming-for-analysts/blob/main/lab_3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
from scipy import *
from scipy.integrate import *
import math
import numpy as np
from numpy.lib.scimath import *
from scipy.integrate import simps
from scipy import integrate
from matplotlib import pyplot as plt

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# **Вариант 1.** Аналитическое решение

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# **Вариант 1.** Решение через модуль Scipy quad-lambda

# %%
result = integrate.quad(lambda x: x**3/(x**8-2),0,1)
result
# Out:
# (-0.15580631003505763, 1.3706114467140702e-12)

# %% [markdown]
# **Вариант 2.** Метод Симпсона

# %%
def f1(x):
  return x**3/(x**8-2)

x=np.arange(0,1.001, 0.001)

y1 = f1(x)
I1 = simps(y1,x)
print(I1)
# Out:
# -0.1558063100789282

# %% [markdown]
# **Вариант 3.** Метод трапеции

# %%
def f1(x):
  return x**3/(x**8-2)

x=np.arange(0,1.001, 0.001)
rezult = trapz(f1(x),x)
rezult
# Out:
# -0.15580722669075409

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)
