# %% [markdown]
# <a href="https://colab.research.google.com/github/SofiaShvedova/Programming-for-analysts/blob/main/lab_6.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from numpy.random import seed
from numpy.random import randn
from numpy import mean
from numpy import std
seed(1)
data = 5 * randn(100) + 50
print('mean=%.3f stdv=%.3f' %(mean(data), std(data)))
# Out:
# mean=50.303 stdv=4.426

# %% [markdown]
# ### **Визуальные проверки нормальности**

# %% [markdown]
# **График гистограммы**

# %%
from matplotlib import pyplot

pyplot.hist(data)
pyplot.show()

# %% [markdown]
# **Квантиль-Квантиль Участок**

# %%
from statsmodels.graphics.gofplots import qqplot

qqplot(data, line='s')
pyplot.show()
# Out:
# /usr/local/lib/python3.7/dist-packages/statsmodels/tools/_testing.py:19: FutureWarning: pandas.util.testing is deprecated. Use the functions in the public API at pandas.testing instead.
#   import pandas.util.testing as tm

# %% [markdown]
# ### **Статистические тесты нормальности**

# %% [markdown]
# **Тест Шапиро-Вилка**

# %%
from scipy.stats import shapiro

stat, p = shapiro(data)
print('Statistics=%.3f, p=%.3f' % (stat, p))
alpha = 0.05
if p > alpha:
  print('Sample looks Gaussian (fail to reject H0)')
else:
  print('Sample doesnt look Gaussian (regect H0)')
# Out:
# Statistics=0.992, p=0.822
# Sample looks Gaussian (fail to reject H0)

# %% [markdown]
# **Тест д'Агостино на K ^ 2**

# %%
from scipy.stats import normaltest

stat, p = normaltest(data)
print('Statistics=%.3f, p=%.3f' % (stat, p))
alpha = 0.05
if p > alpha:
  print('Sample looks Gaussian (fail to reject H0)')
else:
  print('Sample doesnt look Gaussian (regect H0)')
# Out:
# Statistics=0.102, p=0.950
# Sample looks Gaussian (fail to reject H0)

# %% [markdown]
# **Тест Андерсона-Дарлинга**

# %%
from scipy.stats import anderson

result = anderson(data)
print('Statistics=%.3f' % result.statistic)
p = 0
for i in range(len(result.critical_values)):
  sl, cv = result.significance_level[1], result.critical_values[1]
  if result.statistic < result.critical_values[1]:
    print('%.3f: %.3f, data looks normal (fail to reject H0)' % (sl, cv))
  else:
    print('%.3f: %.3f, data doestn look normal (reject H0)' % (sl, cv))
# Out:
# Statistics=0.220
# 10.000: 0.632, data looks normal (fail to reject H0)
# 10.000: 0.632, data looks normal (fail to reject H0)
# 10.000: 0.632, data looks normal (fail to reject H0)
# 10.000: 0.632, data looks normal (fail to reject H0)
# 10.000: 0.632, data looks normal (fail to reject H0)

# %% [markdown]
# ### **Индивидуальное задание**

# %%
from numpy import mean
from numpy import std

#importing the libraries
import requests
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
#Importing the data from the webpage into a DataFrame
url='https://en.wikipedia.org/wiki/List_of_highest-grossing_films_in_the_United_Kingdom'
req=requests.get(url)
data=pd.read_html(req.text)
df=data[3]
df
# Out:
#                                                  Rank  \
# 0                                                  01
# 1                                                  02
# 2                                                  03
# 3                                                  04
# 4                                                  05
# 5                                                  06
# 6                                                  07
# 7                                                  08
# 8                                                  09
# 9                                                  10
# 10                                                 11
# 11                                                 12
# 12                                                 13
# 13                                                 14
# 14                                                 15
# 15                                                 16
# 16                                                 17
# 17                                                 18
# 18                                                 19
# 19                                                 20
# 20                                                 21
# 21                                                 22
# 22                                                 23
# 23                                                 24
# 24                                                 25
# 25                                                 26
# 26                                                 27
# 27                                                 28
# 28                                                 29
# 29                                                 30
# 30                                                 31
# 31                                                 32
# 32                                                 33
# 33                                                 34
# 34                                                 35
# 35                                                 36
# 36                                                 37
# 37                                                 38
# 38                                                 39
# 39                                                 40
# 40  Films marked as are classified as British by t...
#
#                                                 Title  \
# 0                        Star Wars: The Force Awakens
# 1                                             Skyfall
# 2                                      No Time to Die
# 3                                             Spectre
# 4                                   Avengers: Endgame
# 5                            Star Wars: The Last Jedi
# 6                                       The Lion King
# 7       Harry Potter and the Deathly Hallows – Part 2
# 8                                Beauty and the Beast
# 9                              Avengers: Infinity War
# 10                                         Mamma Mia!
# 11           Harry Potter and the Philosopher's Stone
# 12                                          Rogue One
# 13                        Mamma Mia! Here We Go Again
# 14                                      Casino Royale
# 15                   Star Wars: The Rise of Skywalker
# 16                                            Dunkirk
# 17                              The Dark Knight Rises
# 18                                  Bohemian Rhapsody
# 19            Harry Potter and the Chamber of Secrets
# 20            Fantastic Beasts and Where to Find Them
# 21      Harry Potter and the Deathly Hallows – Part 1
# 22                                     The Full Monty
# 23                                  Quantum of Solace
# 24             Harry Potter and the Half-Blood Prince
# 25          Harry Potter and the Order of the Phoenix
# 26                                    The Dark Knight
# 27                Harry Potter and the Goblet of Fire
# 28                            Avengers: Age of Ultron
# 29                               Bridget Jones's Baby
# 30                                    The Jungle Book
# 31           Harry Potter and the Prisoner of Azkaban
# 32                                  The King's Speech
# 33                             The Inbetweeners Movie
# 34                               Mary Poppins Returns
# 35                                               1917
# 36                                       Paddington 2
# 37                              Bridget Jones's Diary
# 38                     Jurassic World: Fallen Kingdom
# 39                                     Les Misérables
# 40  Films marked as are classified as British by t...
#
#                                      Gross(£ million)  \
# 0                                               123.2
# 1                                               103.2
# 2                                          96.7[3][4]
# 3                                                95.2
# 4                                                88.7
# 5                                                82.7
# 6                                             76.0[6]
# 7                                             73.1[7]
# 8                                                72.4
# 9                                                70.8
# 10                                            68.9[8]
# 11                                         67.4[nb 1]
# 12                                            66.0[9]
# 13                                           65.6[10]
# 14                                         64.0[nb 2]
# 15                                           58.3[11]
# 16                                           56.8[13]
# 17                                           56.4[14]
# 18                                           55.4[15]
# 19                                           55.0[16]
# 20                                           54.7[17]
# 21                                            52.6[7]
# 22                                               52.2
# 23                                               51.2
# 24                                            50.9[7]
# 25                                            50.0[7]
# 26                                           49.3[14]
# 27                                           49.3[16]
# 28                                               48.3
# 29                                               48.2
# 30                                           46.2[11]
# 31                                           46.3[16]
# 32                                               45.7
# 33                                               45.0
# 34                                           44.5[31]
# 35                                           44.1[10]
# 36                                            42.6[5]
# 37                                               42.0
# 38                                               41.6
# 39                                               40.8
# 40  Films marked as are classified as British by t...
#
#                                                  Year
# 0                                                2015
# 1                                                2012
# 2                                                2021
# 3                                                2015
# 4                                                2019
# 5                                                2017
# 6                                                2019
# 7                                                2011
# 8                                                2017
# 9                                                2018
# 10                                               2008
# 11                                               2001
# 12                                               2016
# 13                                               2018
# 14                                               2006
# 15                                               2019
# 16                                               2017
# 17                                               2012
# 18                                               2018
# 19                                               2002
# 20                                               2016
# 21                                               2011
# 22                                               1997
# 23                                               2008
# 24                                               2009
# 25                                               2007
# 26                                               2008
# 27                                               2005
# 28                                               2015
# 29                                               2016
# 30                                               2016
# 31                                               2004
# 32                                               2011
# 33                                               2011
# 34                                               2018
# 35                                               2019
# 36                                               2017
# 37                                               2001
# 38                                               2018
# 39                                               2013
# 40  Films marked as are classified as British by t...

# %%
df['Rank']=df['Rank'].str.replace(r"*","")
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:1: FutureWarning: The default value of regex will change from True to False in a future version. In addition, single character regular expressions will *not* be treated as literal strings when regex=True.
#   """Entry point for launching an IPython kernel.

# %%
df.head()
# Out:
#   Rank                         Title Gross(£ million)  Year
# 0   01  Star Wars: The Force Awakens            123.2  2015
# 1   02                       Skyfall            103.2  2012
# 2   03                No Time to Die       96.7[3][4]  2021
# 3   04                       Spectre             95.2  2015
# 4   05             Avengers: Endgame             88.7  2019

# %%
df['Gross(£ million)']=df['Gross(£ million)'].str.replace(r"\[[^\]]+\]","").str.replace(r".","")
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:1: FutureWarning: The default value of regex will change from True to False in a future version.
#   """Entry point for launching an IPython kernel.
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:1: FutureWarning: The default value of regex will change from True to False in a future version. In addition, single character regular expressions will *not* be treated as literal strings when regex=True.
#   """Entry point for launching an IPython kernel.

# %%
df.head()
# Out:
#   Rank                         Title Gross(£ million)  Year
# 0   01  Star Wars: The Force Awakens             1232  2015
# 1   02                       Skyfall             1032  2012
# 2   03                No Time to Die              967  2021
# 3   04                       Spectre              952  2015
# 4   05             Avengers: Endgame              887  2019

# %%
df.drop(['Rank'],axis=1,inplace=True)

# %%
df
# Out:
#                                                 Title  \
# 0                        Star Wars: The Force Awakens
# 1                                             Skyfall
# 2                                      No Time to Die
# 3                                             Spectre
# 4                                   Avengers: Endgame
# 5                            Star Wars: The Last Jedi
# 6                                       The Lion King
# 7       Harry Potter and the Deathly Hallows – Part 2
# 8                                Beauty and the Beast
# 9                              Avengers: Infinity War
# 10                                         Mamma Mia!
# 11           Harry Potter and the Philosopher's Stone
# 12                                          Rogue One
# 13                        Mamma Mia! Here We Go Again
# 14                                      Casino Royale
# 15                   Star Wars: The Rise of Skywalker
# 16                                            Dunkirk
# 17                              The Dark Knight Rises
# 18                                  Bohemian Rhapsody
# 19            Harry Potter and the Chamber of Secrets
# 20            Fantastic Beasts and Where to Find Them
# 21      Harry Potter and the Deathly Hallows – Part 1
# 22                                     The Full Monty
# 23                                  Quantum of Solace
# 24             Harry Potter and the Half-Blood Prince
# 25          Harry Potter and the Order of the Phoenix
# 26                                    The Dark Knight
# 27                Harry Potter and the Goblet of Fire
# 28                            Avengers: Age of Ultron
# 29                               Bridget Jones's Baby
# 30                                    The Jungle Book
# 31           Harry Potter and the Prisoner of Azkaban
# 32                                  The King's Speech
# 33                             The Inbetweeners Movie
# 34                               Mary Poppins Returns
# 35                                               1917
# 36                                       Paddington 2
# 37                              Bridget Jones's Diary
# 38                     Jurassic World: Fallen Kingdom
# 39                                     Les Misérables
# 40  Films marked as are classified as British by t...
#
#                                      Gross(£ million)  \
# 0                                                1232
# 1                                                1032
# 2                                                 967
# 3                                                 952
# 4                                                 887
# 5                                                 827
# 6                                                 760
# 7                                                 731
# 8                                                 724
# 9                                                 708
# 10                                                689
# 11                                                674
# 12                                                660
# 13                                                656
# 14                                                640
# 15                                                583
# 16                                                568
# 17                                                564
# 18                                                554
# 19                                                550
# 20                                                547
# 21                                                526
# 22                                                522
# 23                                                512
# 24                                                509
# 25                                                500
# 26                                                493
# 27                                                493
# 28                                                483
# 29                                                482
# 30                                                462
# 31                                                463
# 32                                                457
# 33                                                450
# 34                                                445
# 35                                                441
# 36                                                426
# 37                                                420
# 38                                                416
# 39                                                408
# 40  Films marked as are classified as British by t...
#
#                                                  Year
# 0                                                2015
# 1                                                2012
# 2                                                2021
# 3                                                2015
# 4                                                2019
# 5                                                2017
# 6                                                2019
# 7                                                2011
# 8                                                2017
# 9                                                2018
# 10                                               2008
# 11                                               2001
# 12                                               2016
# 13                                               2018
# 14                                               2006
# 15                                               2019
# 16                                               2017
# 17                                               2012
# 18                                               2018
# 19                                               2002
# 20                                               2016
# 21                                               2011
# 22                                               1997
# 23                                               2008
# 24                                               2009
# 25                                               2007
# 26                                               2008
# 27                                               2005
# 28                                               2015
# 29                                               2016
# 30                                               2016
# 31                                               2004
# 32                                               2011
# 33                                               2011
# 34                                               2018
# 35                                               2019
# 36                                               2017
# 37                                               2001
# 38                                               2018
# 39                                               2013
# 40  Films marked as are classified as British by t...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 41 entries, 0 to 40
# Data columns (total 3 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Title             41 non-null     object
#  1   Gross(£ million)  41 non-null     object
#  2   Year              41 non-null     object
# dtypes: object(3)
# memory usage: 1.1+ KB

# %%
df.drop(labels = [40],axis = 0, inplace=True)

# %%
df.rename(columns={'Gross(£ million)':'Gross'}, inplace=True)

# %%
df['Gross']=df['Gross'].astype('int64')

# %%
df1=df[['Title','Gross']].sort_values(ascending=False,by='Gross')

# %%
df.head()
# Out:
#                           Title  Gross  Year
# 0  Star Wars: The Force Awakens   1232  2015
# 1                       Skyfall   1032  2012
# 2                No Time to Die    967  2021
# 3                       Spectre    952  2015
# 4             Avengers: Endgame    887  2019

# %%
data = df['Gross']
print('mean=%.3f stdv=%.3f' %(mean(data), std(data)))
# Out:
# mean=610.325 stdv=188.905

# %% [markdown]
# # **Визуальные проверки нормальности**

# %% [markdown]
# **График гистограммы**

# %%
from matplotlib import pyplot

pyplot.hist(data)
pyplot.show()

# %% [markdown]
# **Квантиль-Квантиль Участок**

# %%
from statsmodels.graphics.gofplots import qqplot

qqplot(data, line='s')
pyplot.show()

# %% [markdown]
# # **Статистические тесты нормальности**

# %% [markdown]
# **Тест Шапиро-Вилка**

# %%
from scipy.stats import shapiro

stat, p = shapiro(data)
print('Statistics=%.3f, p=%.3f' % (stat, p))
alpha = 0.05
if p > alpha:
  print('Sample looks Gaussian (fail to reject H0)')
else:
  print('Sample doesnt look Gaussian (regect H0)')
# Out:
# Statistics=0.853, p=0.000
# Sample doesnt look Gaussian (regect H0)

# %% [markdown]
# **Тест д'Агостино на K ^ 2**

# %%
from scipy.stats import normaltest

stat, p = normaltest(data)
print('Statistics=%.3f, p=%.3f' % (stat, p))
alpha = 0.05
if p > alpha:
  print('Sample looks Gaussian (fail to reject H0)')
else:
  print('Sample doesnt look Gaussian (regect H0)')
# Out:
# Statistics=15.346, p=0.000
# Sample doesnt look Gaussian (regect H0)

# %% [markdown]
# **Тест Андерсона-Дарлинга**

# %%
from scipy.stats import anderson

result = anderson(data)
print('Statistics=%.3f' % result.statistic)
p = 0
for i in range(len(result.critical_values)):
  sl, cv = result.significance_level[1], result.critical_values[1]
  if result.statistic < result.critical_values[1]:
    print('%.3f: %.3f, data looks normal (fail to reject H0)' % (sl, cv))
  else:
    print('%.3f: %.3f, data doestn look normal (reject H0)' % (sl, cv))
# Out:
# Statistics=1.882
# 10.000: 0.605, data doestn look normal (reject H0)
# 10.000: 0.605, data doestn look normal (reject H0)
# 10.000: 0.605, data doestn look normal (reject H0)
# 10.000: 0.605, data doestn look normal (reject H0)
# 10.000: 0.605, data doestn look normal (reject H0)
